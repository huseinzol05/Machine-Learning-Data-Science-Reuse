# %%
import pandas as pd
from fuzzywuzzy import fuzz
from sklearn.neighbors import NearestNeighbors
import numpy as np
import time
anime = pd.read_csv('anime.csv')
anime = anime.dropna()
print(anime.shape)
anime.head()
# Out:
# (12017, 7)
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
genre_vector = anime.genre.values
genre = []
for i in range(genre_vector.shape[0]):
    try:
        genre.append('|'.join(i.strip()for i in genre_vector[i].split(',')))
    except:
        genre.append('')
anime.genre=genre

# %%
list_genres=list(filter(None, list(set('|'.join(anime.genre.values.tolist()).split('|')))))
list_genres
# Out:
# ['School',
#  'Super Power',
#  'Yuri',
#  'Parody',
#  'Game',
#  'Samurai',
#  'Music',
#  'Fantasy',
#  'Ecchi',
#  'Comedy',
#  'Slice of Life',
#  'Space',
#  'Thriller',
#  'Mecha',
#  'Psychological',
#  'Historical',
#  'Police',
#  'Cars',
#  'Dementia',
#  'Sci-Fi',
#  'Mystery',
#  'Vampire',
#  'Magic',
#  'Drama',
#  'Josei',
#  'Yaoi',
#  'Shounen Ai',
#  'Shoujo Ai',
#  'Shoujo',
#  'Hentai',
#  'Adventure',
#  'Romance',
#  'Demons',
#  'Martial Arts',
#  'Action',
#  'Supernatural',
#  'Shounen',
#  'Military',
#  'Horror',
#  'Seinen',
#  'Sports',
#  'Harem',
#  'Kids']

# %%
list_types = anime.type.unique().tolist()
list_types
# Out:
# ['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA']

# %% [markdown]
# ![alt text](CodeCogsEqn.png)

# %%
gaussian_filter_2d = lambda x,y,sigma: np.exp((-x**2 -y**2)/(2 * sigma ** 2))

# %%
def add_dimension(df, variables, columns):
    shape_len = df.shape[1]
    df = np.hstack([df, np.zeros((df.shape[0], len(variables)))])
    for i in columns:
        for k in range(df.shape[0]):
            if not df[k,i]:
                continue
            try:
                for s in df[k,i].split('|'):
                    if s in variables:
                        df[k,shape_len+variables.index(s)] += 1
            except Exception as e:
                print(e)
                continue
    return df

# %%
def recommend(chosen_index, count_neigh):
    df_copy = anime.copy().values   
    variables = list_genres + list_types
    df_copy = add_dimension(df_copy, variables, [2, 3])
    df_copy = df_copy[:,anime.shape[1]:].astype('float')
    df_copy = df_copy[~np.isnan(df_copy).any(axis=1)]
    neighbors = NearestNeighbors(n_neighbors=count_neigh+1, algorithm='auto', metric='sqeuclidean').fit(df_copy)
    xtest = df_copy[chosen_index, :]
    xtest = xtest.reshape(1, -1)
    distances, indices = neighbors.kneighbors(xtest)
    results = indices[0][:].tolist()
    try:
        del results[results.index(chosen_index)]
    except:
        results=results[:count_neigh]
        pass
    return results

# %%
def sequel(title_1, title_2):    
    if fuzz.ratio(title_1, title_2) > 60 or fuzz.token_set_ratio(title_1, title_2) > 60:
        return True
    else:
        return False

def sort_distribution(title_main, std_users, title, score, user):
    if score:
        factor_e = gaussian_filter_2d(score, user, std_users)
    else:
        factor_e = -999999999
    if sequel(title_main, title):
        gaussian = 0
    else:
        gaussian = (1 / (np.pi * 2 * std_users ** 2)) * factor_e
    return gaussian

# %%
def extract_ratings(chosen_index, list_films, count_neigh):
    parametres_anime = ['_' for _ in range(count_neigh)]
    users = []
    for i, index in enumerate(list_films):
        parametres_anime[i] = anime[['name','rating','members']].iloc[index].tolist()
        parametres_anime[i].append(index)
        users.append(parametres_anime[i][2])
    
    title_main = anime['name'].iloc[chosen_index]
    users.append(anime['members'].iloc[chosen_index])
    std_users = np.std(users)
    results_gaussian = [sort_distribution(title_main,std_users,x[0],x[1],x[2]) for x in parametres_anime]
    results = np.array(parametres_anime)[(np.array(results_gaussian).argsort())]
    return results[:,-1].tolist()

# %%
dragonball_index = np.argmax([fuzz.ratio('dragon ball z', i) for i in anime.name.values])
print(dragonball_index)
suggest_number = 10
print('random selected:')
print(anime.iloc[dragonball_index,:])
recommended = recommend(dragonball_index, suggest_number)
sorted_recommended = np.array(extract_ratings(dragonball_index,recommended,suggest_number)).astype('int')
# Out:
# 206
# random selected:
# anime_id                                                  813
# name                                            Dragon Ball Z
# genre       Action|Adventure|Comedy|Fantasy|Martial Arts|S...
# type                                                       TV
# episodes                                                  291
# rating                                                   8.32
# members                                                375662
# Name: 206, dtype: object

# %% [markdown]
# ## without sorting

# %%
anime.iloc[recommended, :]
# Out:
#       anime_id                                               name  \
# 588       6033                                    Dragon Ball Kai
# 1930     30694                                  Dragon Ball Super
# 515      22777                             Dragon Ball Kai (2014)
# 346        223                                        Dragon Ball
# 1796       238                                     Rekka no Honoo
# 4701      4427                                 Tatakae!! Ramenman
# 4275      6714               Dragon Ball Z: Atsumare! Gokuu World
# 841         20                                             Naruto
# 4595     11385  Digimon Xros Wars: Toki wo Kakeru Shounen Hunt...
# 3203     22695             Dragon Ball Z: Summer Vacation Special
#
#                                                   genre     type episodes  \
# 588   Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV       97
# 1930  Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV  Unknown
# 515   Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV       61
# 346   Adventure|Comedy|Fantasy|Martial Arts|Shounen|...       TV      153
# 1796  Action|Adventure|Martial Arts|Shounen|Super Power       TV       42
# 4701       Action|Adventure|Comedy|Martial Arts|Shounen       TV       35
# 4275  Action|Adventure|Comedy|Fantasy|Martial Arts|S...      OVA        1
# 841      Action|Comedy|Martial Arts|Shounen|Super Power       TV      220
# 4595            Action|Adventure|Comedy|Fantasy|Shounen       TV       25
# 3203  Action|Adventure|Comedy|Fantasy|Martial Arts|S...  Special        1
#
#       rating  members
# 588     7.95   116832
# 1930    7.40   111443
# 515     8.01    42666
# 346     8.16   316102
# 1796    7.44    35258
# 4701    6.66      431
# 4275    6.76    10044
# 841     7.81   683297
# 4595    6.68    11963
# 3203    7.05     4251

# %% [markdown]
# ## with gaussian sorting

# %%
anime.iloc[sorted_recommended,:]
# Out:
#       anime_id                                               name  \
# 588       6033                                    Dragon Ball Kai
# 1930     30694                                  Dragon Ball Super
# 515      22777                             Dragon Ball Kai (2014)
# 346        223                                        Dragon Ball
# 4275      6714               Dragon Ball Z: Atsumare! Gokuu World
# 3203     22695             Dragon Ball Z: Summer Vacation Special
# 841         20                                             Naruto
# 1796       238                                     Rekka no Honoo
# 4595     11385  Digimon Xros Wars: Toki wo Kakeru Shounen Hunt...
# 4701      4427                                 Tatakae!! Ramenman
#
#                                                   genre     type episodes  \
# 588   Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV       97
# 1930  Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV  Unknown
# 515   Action|Adventure|Comedy|Fantasy|Martial Arts|S...       TV       61
# 346   Adventure|Comedy|Fantasy|Martial Arts|Shounen|...       TV      153
# 4275  Action|Adventure|Comedy|Fantasy|Martial Arts|S...      OVA        1
# 3203  Action|Adventure|Comedy|Fantasy|Martial Arts|S...  Special        1
# 841      Action|Comedy|Martial Arts|Shounen|Super Power       TV      220
# 1796  Action|Adventure|Martial Arts|Shounen|Super Power       TV       42
# 4595            Action|Adventure|Comedy|Fantasy|Shounen       TV       25
# 4701       Action|Adventure|Comedy|Martial Arts|Shounen       TV       35
#
#       rating  members
# 588     7.95   116832
# 1930    7.40   111443
# 515     8.01    42666
# 346     8.16   316102
# 4275    6.76    10044
# 3203    7.05     4251
# 841     7.81   683297
# 1796    7.44    35258
# 4595    6.68    11963
# 4701    6.66      431

# %%
outputs, i = [], 0
while len(outputs) < suggest_number:
    recommended = recommend(dragonball_index, suggest_number * (i+2))
    if not sequel(anime.name.iloc[dragonball_index], anime.name.iloc[recommended[i]]) and recommended[i] not in outputs:
        outputs.append(recommended[i])
    i += 1
sorted_recommended = np.array(extract_ratings(dragonball_index,outputs,suggest_number)).astype('int')

# %% [markdown]
# ## remove sequel

# %%
anime.iloc[sorted_recommended,:]
# Out:
#       anime_id                                               name  \
# 841         20                                             Naruto
# 615       1735                                 Naruto: Shippuuden
# 74          21                                          One Piece
# 989      10033                                             Toriko
# 2723       461  One Piece Movie 3: Chinjuu-jima no Chopper Oukoku
# 1796       238                                     Rekka no Honoo
# 4960     12929                                  Saint Seiya Omega
# 2913      2335                              Kenyuu Densetsu Yaiba
# 2934       961                                     Virtua Fighter
# 9673     27943                                      Nano Invaders
#
#                                                   genre   type episodes  \
# 841      Action|Comedy|Martial Arts|Shounen|Super Power     TV      220
# 615      Action|Comedy|Martial Arts|Shounen|Super Power     TV  Unknown
# 74    Action|Adventure|Comedy|Drama|Fantasy|Shounen|...     TV  Unknown
# 989             Action|Adventure|Comedy|Fantasy|Shounen     TV      147
# 2723  Action|Adventure|Comedy|Fantasy|Shounen|Super ...  Movie        1
# 1796  Action|Adventure|Martial Arts|Shounen|Super Power     TV       42
# 4960                   Action|Adventure|Fantasy|Shounen     TV       97
# 2913         Action|Comedy|Fantasy|Martial Arts|Shounen     TV       52
# 2934       Action|Adventure|Comedy|Martial Arts|Shounen     TV       35
# 9673               Action|Adventure|Shounen|Super Power     TV       52
#
#       rating  members
# 841     7.81   683297
# 615     7.94   533578
# 74      8.58   504862
# 989     7.74    54790
# 2723    7.18    36558
# 1796    7.44    35258
# 4960    6.59    22684
# 2913    7.13     5158
# 2934    7.13     3875
# 9673    7.08      519

# %%
def suggest_me_anime(keyword, suggest_count, remove_sequel=True):
    lasttime = time.time()
    your_index = np.argmax([fuzz.ratio(keyword, i) for i in anime.name.values])
    print('your selection:')
    print(anime.iloc[your_index,:])
    if remove_sequel:
        outputs, i = [], 0
        while len(outputs) < suggest_count:
            recommended = recommend(your_index, suggest_count * (i+2))
            if not sequel(anime.name.iloc[your_index], anime.name.iloc[recommended[i]]) and recommended[i] not in outputs:
                outputs.append(recommended[i])
            i += 1
        results = np.array(extract_ratings(your_index,outputs,suggest_count)).astype('int')
    else:
        recommended = recommend(your_index, suggest_count)
        results = np.array(extract_ratings(your_index,recommended,suggest_count)).astype('int')
    print('time taken to suggest:', time.time()-lasttime, 'seconds')
    return results

# %%
anime.iloc[suggest_me_anime('kimi no nawa', 20, remove_sequel=True),:]
# Out:
# your selection:
# anime_id                                32281
# name                           Kimi no Na wa.
# genre       Drama|Romance|School|Supernatural
# type                                    Movie
# episodes                                    1
# rating                                   9.37
# members                                200630
# Name: 0, dtype: object
# time taken to suggest: 2.4941344261169434 seconds
#        anime_id                                               name  \
# 60        10408                                 Hotarubi no Mori e
# 2103       1723                                      Clannad Movie
# 1959        713                                          Air Movie
# 1697      31245  Zutto Mae kara Suki deshita.: Kokuhaku Jikkou ...
# 1111      14669              Aura: Maryuuin Kouga Saigo no Tatakai
# 3530       9988       Otome wa Boku ni Koishiteru: Futari no Elder
# 6394        546                       Wind: A Breath of Heart (TV)
# 6315      22847       Kara no Kyoukai: Mirai Fukuin - Manner Movie
# 3914      17585                         Myself ; Yourself Specials
# 3908      18053   Koi to Senkyo to Chocolate: Ikenai Hazuki-sensei
# 5805        547                        Wind: A Breath of Heart OVA
# 3391       2029                                 Sirius no Densetsu
# 6119       7510                                      Shisha no Sho
# 5869       7376                                 Kurumiwari Ningyou
# 9602      10758                                          Momotarou
# 8656       9351                              Geunyeoneun Yeppeotda
# 10425      7683                                     Suiren no Hito
# 9013      29623                                 Jiaoao de Jiangjun
# 10141     30059                                   Saru Kani Gassen
# 9754      29900                                             Nobara
#
#                                           genre     type episodes  rating  \
# 60            Drama|Romance|Shoujo|Supernatural    Movie        1    8.61
# 2103               Drama|Fantasy|Romance|School    Movie        1    7.35
# 1959                 Drama|Romance|Supernatural    Movie        1    7.39
# 1697                             Romance|School    Movie        1    7.47
# 1111   Comedy|Drama|Romance|School|Supernatural    Movie        1    7.67
# 3530                       Drama|Romance|School      OVA        3    6.96
# 6394          Drama|Romance|School|Supernatural       TV       13    6.14
# 6315                                      Drama    Movie        1    6.17
# 3914                       Drama|Romance|School  Special        2    6.85
# 3908                       Drama|Romance|School  Special        1    6.85
# 5805          Drama|Romance|School|Supernatural      OVA        3    6.35
# 3391                      Drama|Fantasy|Romance    Movie        1    7.01
# 6119                         Drama|Supernatural    Movie        1    6.25
# 5869                      Drama|Fantasy|Romance    Movie        1    6.33
# 9602                                      Drama    Movie        1    5.57
# 8656                       Comedy|Drama|Romance    Movie        1    6.65
# 10425                                     Drama    Movie        1    6.00
# 9013                                      Drama    Movie        1    5.64
# 10141                                     Drama    Movie        1    4.75
# 9754                                      Drama    Movie        1    4.59
#
#        members
# 60      197439
# 2103     99506
# 1959     44179
# 1697     35058
# 1111     22599
# 3530     10579
# 6394      7778
# 6315      4260
# 3914      4128
# 3908      3526
# 5805      2043
# 3391      2007
# 6119       722
# 5869       225
