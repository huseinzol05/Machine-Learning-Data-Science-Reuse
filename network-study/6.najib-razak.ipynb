# %%
from followers import *

# %%
matches = api.lookup_users(screen_names=['NajibRazak'])

# %%
data, accepted_list = get_follower_ids(matches[0].id,matches[0].id,max_depth=1)
# Out:
# 811786659343630336	myTN50	TN50
#
# 848744329208152064	TheRakyatRasmi	TheRakyat
#
# 375146901	donaldtusk	Donald Tusk
#
# 196994616	eucopresident	Donald Tusk
#
# 119062652	DrNovandri	Dr Novandri
#
# 1497713646	OfficialMIDA	MIDA
#
# 837638271467335680	mahsiewkeong8	Mah Siew Keong
#
# 837667256377102336	dswanjunaidi	DS Wan Junaidi TJ
#
# 25073877	realDonaldTrump	Donald J. Trump
#
# 171858132	tontonmy	tonton
#
# 31073523	ntv7malaysia	ntv7 Malaysia
#
# 31074710	tv9malaysia	TV9 Malaysia
#
# 29157016	tv3malaysia	tv3malaysia
#
# 155432431	BuletinTV3	Berita TV3
#
# Rate limited. Sleeping for 15 mins.
# 63070015	hmetromy	Harian Metro
#
# 385323351	MRTMalaysia	Mass Rapid Transit
#
# 747807250819981312	theresa_may	Theresa May
#
# 157632811	patrickgrove	Patrick Grove
#
# 343364405	PScotlandCSG	Patricia Scotland QC
#
# 724460446766374912	NTPMalaysia	NTP Malaysia
#
# 182628394	ammir50	Muhammad Ammir Haron
#
# 2331510720	1MNegaraku	1Malaysia
#
# 398670879	YBAhmadRazif	Ahmad Razif Abd Rahman
#
# ...

# %%
len(data)
# Out:
# 149

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head(50)
# Out:
#       centre  followers_count  \
# 0   16389180          4109573
# 1   16389180            12904
# 2   16389180            20654
# 3   16389180          1029079
# 4   16389180           865084
# 5   16389180            13901
# 6   16389180             9353
# 7   16389180             1331
# 8   16389180             1173
# 9   16389180         51029265
# 10  16389180           123228
# 11  16389180            66232
# 12  16389180           695643
# 13  16389180          1084918
# 14  16389180           817004
# 15  16389180            27768
# 16  16389180           524998
# 17  16389180             9140
# 18  16389180            11241
# 19  16389180             1253
# 20  16389180             1949
# 21  16389180             7258
# 22  16389180             5853
# 23  16389180             1248
# 24  16389180             6439
# 25  16389180             5752
# 26  16389180            24086
# 27  16389180            17612
# 28  16389180             2012
# 29  16389180            21430
# ...

# %%
df.to_csv('NajibRazak.csv',index=False)
